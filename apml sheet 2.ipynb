# %%
# (c)
N, m1, m2, s1, s2, b = 20, 8, 12, 2, 2, 3
# Out:
# (20, 8, 12, 2, 2, 3)

# %%
# (a)
f1(s1) =    (2*pi*s1^2)^-0.5 * exp(-1/(2s1^2)*(s1-m1))
f2(s1,p1) = (2*pi*b^2 )^-0.5 * exp(-1/(2b^2)*(p1-s1))
f3(s2) =    (2*pi*s2^2)^-0.5 * exp(-1/(2s2^2)*(s2-m2))
# Out:
# f2 (generic function with 1 method)

# %%
# Out:
# 11.361527807246743

# %%
# (b)
